# %%
import bokeh.io
import bokeh.plotting
bokeh.io.output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="a11460c1-116e-4d2c-b13e-c6dd6c0f5e18">Loading BokehJS ...</span>
#     </div>

# %%
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers

output_file("test.html")

p = figure(title = "my first bokeh")
p.xaxis.axis_label = "patel length"
p.yaxis.axis_label = "patel width"
p.circle(flowers["petal_length"] , flowers["petal_width"])
show(p)
# Out:
#   <div id="d7e0e5ae-607c-4d12-be12-cab2b76d2e8b" data-root-id="p1001" style="display: contents;"></div>

# %%
from bokeh.plotting import figure,output_file,show
from bokeh.sampledata.iris import flowers

output_file("test.html")

p = figure(title = "my line bokeh")
p.xaxis.axis_label = "x axis"
p.yaxis.axis_label = "y axis"
p.line(flowers["petal_length"] , flowers["petal_width"])
show(p)
# Out:
#   <div id="a3144378-f5d5-476a-94b7-eae996bd78a2" data-root-id="p1044" style="display: contents;"></div>

# %%
x = [2,3,4,5,6]
y = [1,3,5,7,9]

output_file("my_custom_plot.html")

p = figure(title="my custom")
p.xaxis.axis_label = "my x-axis"
p.yaxis.axis_label = "my y-axis"
p.line(x,y)
show(p)
# Out:
#   <div id="bb12bfa3-2790-4625-bbd8-29a60206e53f" data-root-id="p1087" style="display: contents;"></div>

# %%
x = [2,3,4,5,6]
y = [1,3,5,7,9]

output_file("my custom plot")

p = figure(title="my custom")
p.xaxis.axis_label = "my x-axis"
p.yaxis.axis_label = "my y-axis"
p.scatter(x,y , fill_color = "red",legend_label = "red",size = 10)
show(p)
# Out:
#   <div id="f29fb5e6-9949-4287-b9e3-ff3d0f2aaeed" data-root-id="p1126" style="display: contents;"></div>
