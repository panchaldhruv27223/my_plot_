# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.scatterplot(x=iris['sepal_length'] , y=iris["sepal_width"])
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x=iris['sepal_length'] , y=iris["petal_length"])
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='petal_length'>

# %%
sns.scatterplot(x=iris['petal_width'] , y=iris["petal_length"])
# Out:
# <AxesSubplot: xlabel='petal_width', ylabel='petal_length'>

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,5))
sns.histplot(x=iris["petal_width"])
plt.xticks(iris["petal_width"])
plt.xlim(left=0)
plt.show()

# %%
sns.histplot(x=iris["petal_width"],kde=True)
# Out:
# <AxesSubplot: xlabel='petal_width', ylabel='Count'>

# %%
sns.displot(iris['sepal_length'])

#  distribution graph.

# %%
sns.histplot(x=iris["sepal_length"])
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='Count'>

# %%
tip = sns.load_dataset('tips')

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.scatterplot(x=tip["total_bill"], y =tip["tip"])
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='tip'>

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tip["smoker"].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x=tip.total_bill , y = tip.tip , data=tip ,hue="smoker")

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = tip.total_bill , y = tip.tip ,data=tip , hue="size")

# %%
sns.relplot(x = tip.total_bill , y = tip.tip ,data=tip , style= "size")

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.relplot(x = tip.total_bill , y = tip.tip ,data=tip , style= "size" , hue="time")

#  relplot can be used when you want to group the data

# %%
#  both hue and style is used for group

#  we can use hue for color 
#  we can use style for symbols

# %%
tip.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x=tip.day , y = tip.total_bill , data=tip)

#  x is catogorical

# %%
sns.catplot(x=tip["smoker"] , y=tip["total_bill"])

# %%
sns.jointplot(x=tip["total_bill"] ,y=tip["tip"])

# %%
sns.pairplot(tip)

#  it take all the numeric columns and create a graph

# %%
sns.pairplot(iris)

# %%
sns.heatmap()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 sns.heatmap(iris)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# ...

# %%
print(sns.get_dataset_names())
# Out:
# ['anagrams', 'anscombe', 'attention', 'brain_networks', 'car_crashes', 'diamonds', 'dots', 'dowjones', 'exercise', 'flights', 'fmri', 'geyser', 'glue', 'healthexp', 'iris', 'mpg', 'penguins', 'planets', 'seaice', 'taxis', 'tips', 'titanic']

# %%
sns.load_dataset("glue")
# Out:
#           Model  Year      Encoder  Task  Score
# 0         ERNIE  2019  Transformer  CoLA   75.5
# 1            T5  2019  Transformer  CoLA   71.6
# 2       RoBERTa  2019  Transformer  CoLA   67.8
# 3          BERT  2018  Transformer  CoLA   60.5
# 4   BiLSTM+ELMo  2018         LSTM  CoLA   32.1
# ..          ...   ...          ...   ...    ...
# 59         BERT  2018  Transformer   RTE   70.1
# 60  BiLSTM+ELMo  2018         LSTM   RTE   57.4
# 61  BiLSTM+CoVe  2017         LSTM   RTE   52.7
# 62  BiLSTM+Attn  2017         LSTM   RTE   58.4
# 63       BiLSTM  2017         LSTM   RTE   57.4
#
# [64 rows x 5 columns]

# %%
sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score"))
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_6228\797947984.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score"))
# <AxesSubplot: xlabel='Task', ylabel='Model'>

# %%
sns.load_dataset("glue").pivot("Model" , "Task" , "Year")
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_6228\1643616669.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.load_dataset("glue").pivot("Model" , "Task" , "Year")
# Task         CoLA  MNLI  MRPC  QNLI   QQP   RTE  SST-2  STS-B
# Model
# BERT         2018  2018  2018  2018  2018  2018   2018   2018
# BiLSTM       2017  2017  2017  2017  2017  2017   2017   2017
# BiLSTM+Attn  2017  2017  2017  2017  2017  2017   2017   2017
# BiLSTM+CoVe  2017  2017  2017  2017  2017  2017   2017   2017
# BiLSTM+ELMo  2018  2018  2018  2018  2018  2018   2018   2018
# ERNIE        2019  2019  2019  2019  2019  2019   2019   2019
# RoBERTa      2019  2019  2019  2019  2019  2019   2019   2019
# T5           2019  2019  2019  2019  2019  2019   2019   2019

# %%
sns.load_dataset("glue").groupby("Model").value_counts()
# Out:
# Model  Year  Encoder      Task   Score
# BERT   2018  Transformer  CoLA   60.5     1
#                           MNLI   86.7     1
#                           MRPC   89.3     1
#                           QNLI   92.7     1
#                           QQP    72.1     1
#                                          ..
# T5     2019  Transformer  QNLI   96.9     1
#                           QQP    75.1     1
#                           RTE    92.8     1
#                           SST-2  97.5     1
#                           STS-B  93.1     1
# Length: 64, dtype: int64

# %%
sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score") , linewidths="1")
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_6228\2155994577.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score") , linewidths="1")
# <AxesSubplot: xlabel='Task', ylabel='Model'>

# %%
sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score") , linewidths="1" , annot=True)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_6228\279976579.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score") , linewidths="1" , annot=True)
# <AxesSubplot: xlabel='Task', ylabel='Model'>

# %%
sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score") , linewidths="1" , annot=True , fmt=".1f")
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_6228\739079442.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score") , linewidths="1" , annot=True , fmt=".1f")
# <AxesSubplot: xlabel='Task', ylabel='Model'>

# %%
sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score") , linewidths="1" , annot=True , fmt=".1f" , vmin=50 , vmax=100)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_6228\4164039795.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   sns.heatmap(sns.load_dataset("glue").pivot("Model" , "Task" , "Score") , linewidths="1" , annot=True , fmt=".1f" , vmin=50 , vmax=100)
# <AxesSubplot: xlabel='Task', ylabel='Model'>

# %%
import seaborn as sns

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(iris[["sepal_length","sepal_width","petal_length","petal_width"]])
# Out:
# <AxesSubplot: >

# %%
sns.lineplot(x=iris["sepal_length"],y=iris["sepal_width"],markers="*",markersize=10)
# Out:
# <AxesSubplot: xlabel='sepal_length', ylabel='sepal_width'>

# %%
iris.corr()
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_30696\2141086772.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   iris.corr()
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.117570      0.871754     0.817941
# sepal_width      -0.117570     1.000000     -0.428440    -0.366126
# petal_length      0.871754    -0.428440      1.000000     0.962865
# petal_width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(iris.corr(),annot=True,fmt="2.3f",linewidths=1,vmin=-1,vmax=1)
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_30696\1534948024.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(iris.corr(),annot=True,fmt="2.3f",linewidths=1,vmin=-1,vmax=1)
# <AxesSubplot: >
