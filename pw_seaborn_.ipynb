# %%
import seaborn as sns

# %%
Q.1: Name any five plots that we can plot using the Seaborn library. Also, state the uses of each plot.

# %%
Seaborn is a powerful data visualization library built on top of Matplotlib, 
designed to make visualizing data more straightforward and aesthetically pleasing. 

sns.scatterplot :
     scatter plots show the relationship between two numerical variables, each represented by a point on the graph.
     It helps visualize the correlation or pattern between the two variables.

sns.barplot :
     Bar plots are used to compare categorical data, typically represented on the x-axis, while the height of the bars
     represents the corresponding values on the y-axis. 
     They are useful for visualizing counts or aggregations of data.

sns.boxplot :
     Box plots, also known as box-and-whisker plots, provide a summary of the distribution of numerical data. 
     They show the median, quartiles, and identify potential outliers in the data.

sns.histplot :
    Histograms display the distribution of a single numerical variable by dividing it into bins and showing the frequency
    or count of data points falling into each bin.

sns.jointplot :
    jointplot is used to visualize the relationship between two numerical variables by plotting their joint distribution 
    along with individual univariate distributions on the x and y axes. It is particularly useful for exploring the 
    correlation and distribution of two variables simultaneously.

sns.pairplot :
     pairplot is used to create a grid of scatter plots to visualize the pairwise relationships between multiple numerical 
     variables in a dataset. 
     It is an excellent tool for understanding correlations and identifying patterns in data with multiple dimensions.
        
sns.heatmap :
    Heatmaps are used to visualize the matrix-like data, where each cell is color represents the value at the intersection
    of a row and column. They are effective for displaying correlations, pairwise relationships, or matrices.

# %%
Q.2: Load the "fmri" dataset using the load_dataset function of seaborn. Plot a line plot using x = 
"timepoint" and y = "signal" for different events and regions. 

Note:  timepoint, signal, event, and region are columns in the fmri dataset.

# %%
fmri = sns.load_dataset("fmri")
fmri
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
fmri['timepoint'].unique()
# Out:
# array([18, 14, 17,  9, 16, 15,  0, 13, 12, 11, 10,  3,  7,  8,  2,  6,  5,
#         4,  1], dtype=int64)

# %%
fmri['signal'].unique()
# Out:
# array([-0.01755158, -0.08088293, -0.08103302, ..., -0.00493911,
#        -0.02536671, -0.00689923])

# %%
fig = sns.lineplot(x = "timepoint", y = "signal", data=fmri)

# %%
Q.3 Load the "titanic" dataset using the load_dataset function of seaborn. Plot two box plots using x = 
'pclass', y = 'age' and y = 'fare'.

Note:  pclass, age, and fare are columns in the titanic dataset.

# %%
titanic = sns.load_dataset("titanic")

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.boxplot(x ='pclass', y = "age" , data = titanic)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(x ='pclass', y = "fare" , data = titanic)
# Out:
# <AxesSubplot: xlabel='pclass', ylabel='fare'>

# %%
Q.4 Use the "diamonds" dataset from seaborn to plot a histogram for the 'price' column. Use the hue 
parameter for the 'cut' column of the diamonds dataset.

# %%
diamond = sns.load_dataset("diamonds")
diamond
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
sns.displot(x="price",data =diamond)

# %%
sns.displot(x="price",data=diamond , hue="cut")

# %%
sns.relplot(x="price" , y="carat" , data=diamond , hue="cut")

# %%
Q.5 Use the "iris" dataset from seaborn to plot a pair plot. Use the hue parameter for the "species" column 
of the iris dataset.

# %%
iris = sns.load_dataset("iris")
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris , hue="species", size=4)
# Out:
# C:\Users\dhruv\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\axisgrid.py:2095: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# Q.6 Use the "flights" dataset from seaborn to plot a heatmap.

# %%
f = sns.load_dataset("flights")
f
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = sns.load_dataset("flights").pivot("month","year","passengers")
flights
# Out:
# C:\Users\dhruv\AppData\Local\Temp\ipykernel_10348\40676057.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   flights = sns.load_dataset("flights").pivot("month","year","passengers")
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# ...

# %%
import pandas as pd
import numpy as np
import datetime

# %%
sns.heatmap(flights , linewidths=0.1,cmap="crest" , vmin=(np.min(flights)).min() , vmax=(np.max(flights)).max() )
# Out:
# C:\Users\dhruv\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.max(axis=None) will return a scalar max over the entire DataFrame. To retain the old behavior, use 'frame.max(axis=0)' or just 'frame.max()'
#   return reduction(axis=axis, out=out, **passkwargs)
# <AxesSubplot: xlabel='year', ylabel='month'>

# %%
(np.min(flights)).min()
# Out:
# C:\Users\dhruv\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:84: FutureWarning: In a future version, DataFrame.min(axis=None) will return a scalar min over the entire DataFrame. To retain the old behavior, use 'frame.min(axis=0)' or just 'frame.min()'
#   return reduction(axis=axis, out=out, **passkwargs)
# 104

# %%
sns.heatmap(flights , linewidths=0.1, cmap="crest",annot=True, fmt=".0f", vmin=(np.min(flights)).min() , vmax=(np.max(flights)).max() )
# Out:
# <AxesSubplot: xlabel='year', ylabel='month'>

# %%
tip = sns.load_dataset("tips")

# %%
tip
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.violinplot(data = tip , x="tip" , y = "total_bill" , color="#2810e7" ,hue="time")
# Out:
# <AxesSubplot: xlabel='tip', ylabel='total_bill'>

# %%
sns.histplot(x=tip.time,kde=True)
# Out:
# <AxesSubplot: xlabel='time', ylabel='Count'>
